# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryu-Santos/CPEN65-2/blob/main/Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Children of Node 16 = 13, 6, 60
# 7. Parent of Node 1 = 7
# 8. Siblings of 23 = None
# 9. Ancestors of 9 = 4, 12, 7, 22
# 10. Descendants of 16 = 13, 23, 6, 60, 21
# 11. Leaves = 23, 6, 21, 20, 9, 1
# 12. Non-leaves = 22, 16, 7, 13, 60, 12, 4
# 13. Depth of Node 4 = Depth 3
# 14. Degree of the tree = Degree 1
# 15. Height of the tree : Node 22 =  Height 4 // Node 16 & 7 = Height 3 // Node 13, 6, 60, 12, & 1 = Height 2 // Node 23, 21, 20, & 4 = Height 1 // Node 9 = Height 0
# 16. Weight of the tree = 6
# 17. Is the tree a binary tree? No.
# 18. Removing 6, is the tree a full binary tree? = No. The degree is still 1.
# 19. Removing 6, is the tree a complete binary tree? = No. All leaves does not have the same depth.
# 20. Is a full binary tree complete? No. All nodes must be filled.
# 21. Is a complete binary tree full? = No. Nodes must have two children.
# 22. How many leaves does a complete n-ary tree of height h have? = n^h
# 23. What is the height of a complete n-ary tree with m leaves? = log**sub**n m
# 24. what is the number of the internal nodes of a complete n-ary tree of height h? = (n^h - 1) / (n - 1)
# 25. What is the total numbers iof nodes a complete n-ary tree of height h have? = 2^h - 1
